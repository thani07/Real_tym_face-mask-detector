# %%
pip install tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow (from versions: none)
# ERROR: No matching distribution found for tensorflow

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
import time
from playsound import playsound
import joblib
import threading

# === Load the model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Load Label Encoder using joblib ===
label_encoder = joblib.load("model/label_encoder_cnn.pkl")

# === Audio files path ===
READY_SOUND = "audio/ready.wav"
WITH_MASK_SOUND = "audio/with_mask.wav"
WITHOUT_MASK_SOUND = "audio/without_mask.wav"

# === Function to play sound in a thread ===
def play_sound(path):
    threading.Thread(target=playsound, args=(path,), daemon=True).start()

# === Load Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("Camera ready. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        face_img = frame[y:y+h, x:x+w]
        face_img_resized = cv2.resize(face_img, (224, 224))
        face_input = np.expand_dims(face_img_resized, axis=0) / 255.0

        prediction = model.predict(face_input)
        class_index = np.argmax(prediction)
        label = label_encoder.inverse_transform([class_index])[0]

        # Draw rectangle and label
        color = (0, 255, 0) if label == "with_mask" else (0, 0, 255)
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

        # Play audio feedback in background thread
        play_sound(READY_SOUND)
        if label == "with_mask":
            play_sound(WITH_MASK_SOUND)
        else:
            play_sound(WITHOUT_MASK_SOUND)

        time.sleep(2)  # Delay to avoid rapid repeat alerts

    cv2.imshow("Face Mask Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\divya\anaconda3\envs\tfenv\lib\site-packages\sklearn\base.py:440: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Camera ready. Press 'q' to quit.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# === Load trained model and label encoder ===
model = load_model("model/mask_detection_cnn_final.h5")

label_map = {
    0: "with_mask",
    1: "without_mask"
}
# === Load Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# === Start webcam ===
cap = cv2.VideoCapture(0)

print("📷 Camera started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)  # Mirror effect
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        face_img = frame[y:y+h, x:x+w]
        face_img_resized = cv2.resize(face_img, (224, 224))  # Make sure your model uses 224x224 input
        face_input = np.expand_dims(face_img_resized, axis=0) / 255.0  # Normalize

        prediction = model.predict(face_input, verbose=0)
        class_index = np.argmax(prediction)
        label = label_map.get(class_index, "Unknown")


        color = (0, 255, 0) if label == "with_mask" else (0, 0, 255)
        label_text = "With Mask" if label == "with_mask" else "No Mask"

        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, label_text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Label encoder using dictionary ===
label_map = {
    1: "with_mask",
    0: "without_mask"
}

# === Load Haar Cascades (frontal + profile) ===
frontal_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
profile_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_profileface.xml")

# === Start webcam ===
cap = cv2.VideoCapture(0)

print("📷 Camera started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)  # Mirror effect
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect face: try frontal first, then profile if not found
    faces = frontal_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
    if len(faces) == 0:
        faces = profile_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    if len(faces) == 0:
        cv2.putText(frame, "No face detected", (30, 30), cv2.FONT_HERSHEY_SIMPLEX,
                    0.8, (0, 255, 255), 2)
    else:
        for (x, y, w, h) in faces:
            face_img = frame[y:y+h, x:x+w]
            face_img_resized = cv2.resize(face_img, (224, 224))  # Match model input size
            face_input = np.expand_dims(face_img_resized, axis=0) / 255.0  # Normalize

            prediction = model.predict(face_input, verbose=0)
            class_index = np.argmax(prediction)
            label = label_map.get(class_index, "Unknown")

            # Drawing logic
            color = (0, 255, 0) if label == "with_mask" else (0, 0, 255)
            label_text = "With Mask" if label == "with_mask" else "No Mask"

            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
            cv2.putText(frame, label_text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX,
                        0.9, color, 2)

    # Show the frame
    cv2.imshow("Mask Detection Live Feed", frame)

    # Exit on 'q' key
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Corrected label map ===
label_map = {
    0: "with_mask",       # class 0: with mask
    1: "without_mask"     # class 1: without mask
}

# === Load Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)  # Mirror effect
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        face_img = frame[y:y+h, x:x+w]
        face_img_resized = cv2.resize(face_img, (224, 224))  # Change to (128,128) if needed
        face_input = np.expand_dims(face_img_resized, axis=0) / 255.0  # Normalize

        prediction = model.predict(face_input, verbose=0)
        class_index = np.argmax(prediction)
        label = label_map.get(class_index, "Unknown")

        # Print raw prediction and debug info
        print(f"Prediction: {prediction}, Class Index: {class_index}, Label: {label}")

        # Set color and label
        color = (0, 255, 0) if label == "with_mask" else (0, 0, 255)
        label_text = "With Mask" if label == "with_mask" else "No Mask"

        # Confidence score
        confidence = prediction[0][class_index]
        display_text = f"{label_text} ({confidence:.2f})"

        # Draw rectangle and label
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, display_text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.
# Prediction: [[0.9595739]], Class Index: 0, Label: with_mask
# Prediction: [[0.86309034]], Class Index: 0, Label: with_mask
# Prediction: [[0.9439301]], Class Index: 0, Label: with_mask
# Prediction: [[0.9078469]], Class Index: 0, Label: with_mask
# Prediction: [[0.92952156]], Class Index: 0, Label: with_mask
# Prediction: [[0.9484013]], Class Index: 0, Label: with_mask
# Prediction: [[0.89172614]], Class Index: 0, Label: with_mask
# Prediction: [[0.77708554]], Class Index: 0, Label: with_mask
# Prediction: [[0.86609954]], Class Index: 0, Label: with_mask
# Prediction: [[0.9366469]], Class Index: 0, Label: with_mask
# Prediction: [[0.8831303]], Class Index: 0, Label: with_mask
# Prediction: [[0.83791435]], Class Index: 0, Label: with_mask
# Prediction: [[0.9290387]], Class Index: 0, Label: with_mask
# Prediction: [[0.9042605]], Class Index: 0, Label: with_mask
# Prediction: [[0.8891673]], Class Index: 0, Label: with_mask
# Prediction: [[0.93412745]], Class Index: 0, Label: with_mask
# Prediction: [[0.8636404]], Class Index: 0, Label: with_mask
# Prediction: [[0.8235454]], Class Index: 0, Label: with_mask
# Prediction: [[0.85221565]], Class Index: 0, Label: with_mask
# Prediction: [[0.8775861]], Class Index: 0, Label: with_mask
# Prediction: [[0.9477288]], Class Index: 0, Label: with_mask
# Prediction: [[0.97314954]], Class Index: 0, Label: with_mask
# Prediction: [[0.9562856]], Class Index: 0, Label: with_mask
# Prediction: [[0.9833707]], Class Index: 0, Label: with_mask
# Prediction: [[0.9746224]], Class Index: 0, Label: with_mask
# Prediction: [[0.9755656]], Class Index: 0, Label: with_mask
# Prediction: [[0.9707657]], Class Index: 0, Label: with_mask
# Prediction: [[0.9670932]], Class Index: 0, Label: with_mask
# Prediction: [[0.9698775]], Class Index: 0, Label: with_mask
# Prediction: [[0.9775297]], Class Index: 0, Label: with_mask
# Prediction: [[0.9282008]], Class Index: 0, Label: with_mask
# Prediction: [[0.9332633]], Class Index: 0, Label: with_mask
# Prediction: [[0.971347]], Class Index: 0, Label: with_mask
# Prediction: [[0.9470491]], Class Index: 0, Label: with_mask
# Prediction: [[0.90759754]], Class Index: 0, Label: with_mask
# Prediction: [[0.9194223]], Class Index: 0, Label: with_mask
# Prediction: [[0.7531776]], Class Index: 0, Label: with_mask
# Prediction: [[0.7813421]], Class Index: 0, Label: with_mask
# Prediction: [[0.8580413]], Class Index: 0, Label: with_mask
# Prediction: [[0.84153825]], Class Index: 0, Label: with_mask
# Prediction: [[0.8593701]], Class Index: 0, Label: with_mask
# Prediction: [[0.94454855]], Class Index: 0, Label: with_mask
# Prediction: [[0.93822247]], Class Index: 0, Label: with_mask
# Prediction: [[0.9319637]], Class Index: 0, Label: with_mask
# Prediction: [[0.9487867]], Class Index: 0, Label: with_mask
# Prediction: [[0.932412]], Class Index: 0, Label: with_mask
# Prediction: [[0.8563582]], Class Index: 0, Label: with_mask
# Prediction: [[0.6101663]], Class Index: 0, Label: with_mask
# Prediction: [[0.9556224]], Class Index: 0, Label: with_mask
# Prediction: [[0.94056404]], Class Index: 0, Label: with_mask
# Prediction: [[0.96348614]], Class Index: 0, Label: with_mask
# Prediction: [[0.899829]], Class Index: 0, Label: with_mask
# Prediction: [[0.94424725]], Class Index: 0, Label: with_mask
# Prediction: [[0.8664652]], Class Index: 0, Label: with_mask
# Prediction: [[0.9491018]], Class Index: 0, Label: with_mask
# Prediction: [[0.95222116]], Class Index: 0, Label: with_mask
# Prediction: [[0.9559375]], Class Index: 0, Label: with_mask
# Prediction: [[0.948789]], Class Index: 0, Label: with_mask
# Prediction: [[0.9606569]], Class Index: 0, Label: with_mask
# Prediction: [[0.978674]], Class Index: 0, Label: with_mask
# Prediction: [[0.89281845]], Class Index: 0, Label: with_mask
# Prediction: [[0.953814]], Class Index: 0, Label: with_mask
# Prediction: [[0.97905177]], Class Index: 0, Label: with_mask
# Prediction: [[0.98766124]], Class Index: 0, Label: with_mask
# Prediction: [[0.42237765]], Class Index: 0, Label: with_mask
# Prediction: [[0.3219813]], Class Index: 0, Label: with_mask
# Prediction: [[0.34354442]], Class Index: 0, Label: with_mask
# Prediction: [[0.9715693]], Class Index: 0, Label: with_mask
# Prediction: [[0.42838883]], Class Index: 0, Label: with_mask
# Prediction: [[0.98576087]], Class Index: 0, Label: with_mask
# Prediction: [[0.98897123]], Class Index: 0, Label: with_mask
# Prediction: [[0.99441445]], Class Index: 0, Label: with_mask
# Prediction: [[0.9889568]], Class Index: 0, Label: with_mask
# Prediction: [[0.9934088]], Class Index: 0, Label: with_mask
# Prediction: [[0.99419814]], Class Index: 0, Label: with_mask
# Prediction: [[0.9809423]], Class Index: 0, Label: with_mask
# Prediction: [[0.99446565]], Class Index: 0, Label: with_mask
# Prediction: [[0.99286664]], Class Index: 0, Label: with_mask
# Prediction: [[0.9935101]], Class Index: 0, Label: with_mask
# Prediction: [[0.9915926]], Class Index: 0, Label: with_mask
# Prediction: [[0.986525]], Class Index: 0, Label: with_mask
# Prediction: [[0.98168385]], Class Index: 0, Label: with_mask
# Prediction: [[0.994517]], Class Index: 0, Label: with_mask
# Prediction: [[0.9909114]], Class Index: 0, Label: with_mask
# Prediction: [[0.9902171]], Class Index: 0, Label: with_mask
# Prediction: [[0.9852951]], Class Index: 0, Label: with_mask
# Prediction: [[0.9933209]], Class Index: 0, Label: with_mask
# Prediction: [[0.99275297]], Class Index: 0, Label: with_mask
# Prediction: [[0.98495334]], Class Index: 0, Label: with_mask
# Prediction: [[0.9912235]], Class Index: 0, Label: with_mask
# Prediction: [[0.993317]], Class Index: 0, Label: with_mask
# Prediction: [[0.9870041]], Class Index: 0, Label: with_mask
# Prediction: [[0.98882324]], Class Index: 0, Label: with_mask
# Prediction: [[0.99005324]], Class Index: 0, Label: with_mask
# Prediction: [[0.9867434]], Class Index: 0, Label: with_mask
# Prediction: [[0.9905187]], Class Index: 0, Label: with_mask
# Prediction: [[0.9316854]], Class Index: 0, Label: with_mask
# Prediction: [[0.32599804]], Class Index: 0, Label: with_mask
# Prediction: [[0.4550815]], Class Index: 0, Label: with_mask
# Prediction: [[0.5513449]], Class Index: 0, Label: with_mask
# Prediction: [[0.8032111]], Class Index: 0, Label: with_mask
# Prediction: [[0.95110744]], Class Index: 0, Label: with_mask
# Prediction: [[0.9850589]], Class Index: 0, Label: with_mask
# Prediction: [[0.985636]], Class Index: 0, Label: with_mask
# Prediction: [[0.97573733]], Class Index: 0, Label: with_mask
# Prediction: [[0.9888754]], Class Index: 0, Label: with_mask
# Prediction: [[0.98980045]], Class Index: 0, Label: with_mask
# Prediction: [[0.9915707]], Class Index: 0, Label: with_mask
# Prediction: [[0.98871297]], Class Index: 0, Label: with_mask
# Prediction: [[0.9861914]], Class Index: 0, Label: with_mask
# Prediction: [[0.8025372]], Class Index: 0, Label: with_mask
# Prediction: [[0.08000986]], Class Index: 0, Label: with_mask
# Prediction: [[0.86828053]], Class Index: 0, Label: with_mask
# Prediction: [[0.9708454]], Class Index: 0, Label: with_mask
# Prediction: [[0.9465247]], Class Index: 0, Label: with_mask
# Prediction: [[0.9253023]], Class Index: 0, Label: with_mask
# Prediction: [[0.7942574]], Class Index: 0, Label: with_mask
# Prediction: [[0.29792622]], Class Index: 0, Label: with_mask
# Prediction: [[0.18145111]], Class Index: 0, Label: with_mask
# Prediction: [[0.93711567]], Class Index: 0, Label: with_mask
# Prediction: [[0.9272912]], Class Index: 0, Label: with_mask
# Prediction: [[0.9777281]], Class Index: 0, Label: with_mask
# Prediction: [[0.9310858]], Class Index: 0, Label: with_mask
# Prediction: [[0.53570175]], Class Index: 0, Label: with_mask
# Prediction: [[0.03257044]], Class Index: 0, Label: with_mask
# Prediction: [[0.02750631]], Class Index: 0, Label: with_mask
# Prediction: [[0.01442599]], Class Index: 0, Label: with_mask
# Prediction: [[0.00888349]], Class Index: 0, Label: with_mask
# Prediction: [[0.02192315]], Class Index: 0, Label: with_mask
# Prediction: [[0.0073479]], Class Index: 0, Label: with_mask
# Prediction: [[0.00619571]], Class Index: 0, Label: with_mask
# Prediction: [[0.02713015]], Class Index: 0, Label: with_mask
# Prediction: [[0.01946805]], Class Index: 0, Label: with_mask
# Prediction: [[0.03733955]], Class Index: 0, Label: with_mask
# Prediction: [[0.03842945]], Class Index: 0, Label: with_mask
# Prediction: [[0.00455531]], Class Index: 0, Label: with_mask
# Prediction: [[0.0480017]], Class Index: 0, Label: with_mask
# Prediction: [[0.02227178]], Class Index: 0, Label: with_mask
# Prediction: [[0.05128432]], Class Index: 0, Label: with_mask
# Prediction: [[0.04901834]], Class Index: 0, Label: with_mask
# Prediction: [[0.01062953]], Class Index: 0, Label: with_mask
# Prediction: [[0.0277858]], Class Index: 0, Label: with_mask
# Prediction: [[0.03077194]], Class Index: 0, Label: with_mask
# Prediction: [[0.02082373]], Class Index: 0, Label: with_mask
# Prediction: [[0.02650171]], Class Index: 0, Label: with_mask
# Prediction: [[0.01833102]], Class Index: 0, Label: with_mask
# Prediction: [[0.02104417]], Class Index: 0, Label: with_mask
# Prediction: [[0.02612883]], Class Index: 0, Label: with_mask
# Prediction: [[0.02303681]], Class Index: 0, Label: with_mask
# Prediction: [[0.03985572]], Class Index: 0, Label: with_mask
# Prediction: [[0.01691696]], Class Index: 0, Label: with_mask
# Prediction: [[0.02090824]], Class Index: 0, Label: with_mask
# Prediction: [[0.03239999]], Class Index: 0, Label: with_mask
# Prediction: [[0.01266803]], Class Index: 0, Label: with_mask
# Prediction: [[0.01040093]], Class Index: 0, Label: with_mask
# Prediction: [[0.01896005]], Class Index: 0, Label: with_mask
# Prediction: [[0.0130092]], Class Index: 0, Label: with_mask
# Prediction: [[0.00872734]], Class Index: 0, Label: with_mask
# Prediction: [[0.01443209]], Class Index: 0, Label: with_mask
# Prediction: [[0.01328093]], Class Index: 0, Label: with_mask
# Prediction: [[0.00781007]], Class Index: 0, Label: with_mask
# Prediction: [[0.00696102]], Class Index: 0, Label: with_mask
# Prediction: [[0.00867128]], Class Index: 0, Label: with_mask
# Prediction: [[0.01634574]], Class Index: 0, Label: with_mask
# Prediction: [[0.01652083]], Class Index: 0, Label: with_mask
# Prediction: [[0.00601382]], Class Index: 0, Label: with_mask
# Prediction: [[0.00920926]], Class Index: 0, Label: with_mask
# Prediction: [[0.01079482]], Class Index: 0, Label: with_mask
# Prediction: [[0.00950023]], Class Index: 0, Label: with_mask
# Prediction: [[0.00345929]], Class Index: 0, Label: with_mask
# Prediction: [[0.00747948]], Class Index: 0, Label: with_mask
# Prediction: [[0.03458881]], Class Index: 0, Label: with_mask
# Prediction: [[0.00453856]], Class Index: 0, Label: with_mask
# Prediction: [[0.00233167]], Class Index: 0, Label: with_mask
# Prediction: [[0.01743781]], Class Index: 0, Label: with_mask
# Prediction: [[0.01512178]], Class Index: 0, Label: with_mask
# Prediction: [[0.01749453]], Class Index: 0, Label: with_mask
# Prediction: [[0.01502226]], Class Index: 0, Label: with_mask
# Prediction: [[0.00941778]], Class Index: 0, Label: with_mask
# Prediction: [[0.00143934]], Class Index: 0, Label: with_mask
# Prediction: [[0.03059755]], Class Index: 0, Label: with_mask
# Prediction: [[0.03720463]], Class Index: 0, Label: with_mask
# Prediction: [[0.93698424]], Class Index: 0, Label: with_mask
# Prediction: [[0.92780465]], Class Index: 0, Label: with_mask
# Prediction: [[0.95458895]], Class Index: 0, Label: with_mask
# Prediction: [[0.95239687]], Class Index: 0, Label: with_mask
# Prediction: [[0.9655529]], Class Index: 0, Label: with_mask
# Prediction: [[0.95955336]], Class Index: 0, Label: with_mask
# Prediction: [[0.9641816]], Class Index: 0, Label: with_mask
# Prediction: [[0.9242843]], Class Index: 0, Label: with_mask
# Prediction: [[0.9212648]], Class Index: 0, Label: with_mask
# Prediction: [[0.97482276]], Class Index: 0, Label: with_mask
# Prediction: [[0.98520434]], Class Index: 0, Label: with_mask
# Prediction: [[0.9860216]], Class Index: 0, Label: with_mask
# Prediction: [[0.9715852]], Class Index: 0, Label: with_mask
# Prediction: [[0.979244]], Class Index: 0, Label: with_mask
# Prediction: [[0.91014475]], Class Index: 0, Label: with_mask
# Prediction: [[0.9716165]], Class Index: 0, Label: with_mask
# Prediction: [[0.735446]], Class Index: 0, Label: with_mask
# Prediction: [[0.96462595]], Class Index: 0, Label: with_mask
# Prediction: [[0.96463233]], Class Index: 0, Label: with_mask
# Prediction: [[0.9643595]], Class Index: 0, Label: with_mask
# Prediction: [[0.9726509]], Class Index: 0, Label: with_mask
# Prediction: [[0.9815853]], Class Index: 0, Label: with_mask
# Prediction: [[0.9859643]], Class Index: 0, Label: with_mask
# Prediction: [[0.9779243]], Class Index: 0, Label: with_mask
# Prediction: [[0.977543]], Class Index: 0, Label: with_mask
# Prediction: [[0.9902541]], Class Index: 0, Label: with_mask
# Prediction: [[0.9874295]], Class Index: 0, Label: with_mask
# Prediction: [[0.9665173]], Class Index: 0, Label: with_mask
# Prediction: [[0.91307974]], Class Index: 0, Label: with_mask
# Prediction: [[0.9716387]], Class Index: 0, Label: with_mask
# Prediction: [[0.9013623]], Class Index: 0, Label: with_mask
# Prediction: [[0.8844575]], Class Index: 0, Label: with_mask
# Prediction: [[0.95564544]], Class Index: 0, Label: with_mask
# Prediction: [[0.9588805]], Class Index: 0, Label: with_mask

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Corrected label map ===
label_map = {
    0: "without_mask",      # class 0: without mask
    1: "with_mask"          # class 1: with mask
}

# === Load Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)  # Mirror effect
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        face_img = frame[y:y+h, x:x+w]
        face_img_resized = cv2.resize(face_img, (224, 224))
        face_input = np.expand_dims(face_img_resized, axis=0) / 255.0  # Normalize

        prediction = model.predict(face_input, verbose=0)
        class_index = np.argmax(prediction)
        confidence = prediction[0][class_index]
        label = label_map.get(class_index, "Unknown")

        print(f"🧠 Prediction: {prediction}, Class Index: {class_index}, Label: {label}")

        # === Set color based on label ===
        color = (0, 255, 0) if label == "with_mask" else (0, 0, 255)
        label_text = "With Mask" if label == "with_mask" else "No Mask"
        display_text = f"{label_text} ({confidence:.2f})"

        # === Draw bounding box and label ===
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, display_text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.
# 🧠 Prediction: [[0.84767735]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.52731913]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7046289]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.84077805]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8187837]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7142362]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.52749324]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8210535]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7455883]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8913747]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8302098]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.47880027]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.5998082]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.6250346]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7470155]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.84553623]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8213254]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8163788]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.70093113]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.903698]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.71413094]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.4039972]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.94051945]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8948512]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9211752]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8522195]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.87564105]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.93155694]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.43411553]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.14369114]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.2557581]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.3492125]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.2717109]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.35729396]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.37919304]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.30891278]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.21968572]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.22558141]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.31852475]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.2604863]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.30554515]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.2690854]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.23272368]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.24497184]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.3579653]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.35752094]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.3896074]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.72381675]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.30633172]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.36480185]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.44257]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.17214756]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.39552686]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.6352371]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.1807257]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.44243157]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.3703461]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.63710046]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.6757679]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.25478336]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.37720057]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.29282546]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7398833]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.33622184]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.19684817]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.27944985]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7390162]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8181461]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8601735]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7873216]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9043915]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9643114]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9406929]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9724257]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9612548]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9520211]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9678388]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.97088647]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.96799207]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.96918315]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.94283605]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.932665]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.9344465]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8371504]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8920253]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.83591986]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.85305727]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.91043425]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.33785495]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.617159]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.5483651]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.34074044]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.6856982]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7549975]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.4169461]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.19206241]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.40793815]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.40046093]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.3411448]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.6932467]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.21931562]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.15623754]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.78513837]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.46960694]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8716434]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8082937]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8036502]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.21217936]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.86825734]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.93028194]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.22559163]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.32330155]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.809692]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.23001899]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.75720185]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.900008]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.67235965]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.90571374]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.8044755]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.7185314]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.89560914]], Class Index: 0, Label: without_mask
# 🧠 Prediction: [[0.6455028]], Class Index: 0, Label: without_mask

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Label map for binary classification ===
label_map = {
    1: "without_mask",
    0: "with_mask"
}

# === Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        face_img = frame[y:y+h, x:x+w]
        face_img_resized = cv2.resize(face_img, (224, 224))
        face_input = np.expand_dims(face_img_resized, axis=0) / 255.0

        prediction = model.predict(face_input, verbose=0)
        prob = prediction[0][0]

        # Fix: convert sigmoid output to class index
        class_index = 1 if prob > 0.5 else 0
        label = label_map[class_index]

        print(f"🧠 Prediction: {prob:.4f}, Class Index: {class_index}, Label: {label}")

        color = (0, 255, 0) if class_index == 1 else (0, 0, 255)
        label_text = "With Mask" if class_index == 1 else "No Mask"
        display_text = f"{label_text} ({prob:.2f})"

        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, display_text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.
# 🧠 Prediction: 0.9624, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9763, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9630, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9524, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6723, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7552, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9841, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9841, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9786, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9818, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9077, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4241, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5618, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8796, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7808, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8926, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7398, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9411, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.2946, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3470, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3813, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.9848, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9562, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9809, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9818, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9650, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9499, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9854, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9705, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5054, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9712, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7030, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6371, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7426, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4816, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.0615, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1286, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4703, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5572, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.2673, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3788, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3863, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5485, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.3773, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2614, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5386, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.3472, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.9664, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9772, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9837, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9820, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9792, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9604, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9329, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9617, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9115, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6853, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5626, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5755, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7107, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5476, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4047, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2940, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3315, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3082, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3676, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4458, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3611, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2717, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3413, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1642, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2245, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1776, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1944, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2190, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1852, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1630, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1550, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2407, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2076, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2471, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1461, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2228, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2145, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.6421, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4293, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3783, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.7640, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.2601, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4518, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1305, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2105, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4224, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2455, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3058, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4520, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2941, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5028, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.2615, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1544, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1158, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1481, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2103, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1876, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.6420, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.2784, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1150, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1832, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4925, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3860, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3335, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3588, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4284, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5658, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5040, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5629, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5927, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6232, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5701, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.3882, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4765, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4274, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4210, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3605, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3119, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2748, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1348, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.1676, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2926, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2317, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2697, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3970, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.7845, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6259, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4736, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2711, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5136, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5762, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6961, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4323, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3278, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.2933, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3739, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.7517, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5153, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4016, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.9562, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9484, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8991, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9484, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9543, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9489, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9651, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9430, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9519, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9475, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9884, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9729, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9790, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7661, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9377, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9585, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9746, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9410, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9125, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9293, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9552, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9276, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5232, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9236, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9578, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9818, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7166, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8119, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.9099, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8863, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8597, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4516, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4606, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.3904, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5923, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.8679, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4500, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.7475, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5277, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.5371, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4759, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.5978, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6585, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6965, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.6658, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.7115, Class Index: 1, Label: without_mask
# 🧠 Prediction: 0.4453, Class Index: 0, Label: with_mask
# 🧠 Prediction: 0.4612, Class Index: 0, Label: with_mask

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import os

# === Load trained CNN model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Try loading label encoder ===
try:
    with open("model/label_encoder_cnn.pkl", "rb") as f:
        label_encoder = pickle.load(f)
        label_map = {i: label for i, label in enumerate(label_encoder.classes_)}
        print("✅ Label encoder loaded.")
except Exception as e:
    print("⚠️ Failed to load label encoder. Using fallback label map.")
    label_map = {
        0: "with_mask",
        1: "without_mask"
    }

# === Load Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 's' to scan, 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)  # Mirror effect
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        # Draw rectangle around face
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 255, 0), 2)
        cv2.putText(frame, "Press 's' to Scan", (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)

    cv2.imshow("📷 Mask Detection - Press 's' to Scan", frame)

    key = cv2.waitKey(1) & 0xFF

    if key == ord('s') and len(faces) > 0:
        print("📸 Scanning face...")
        for (x, y, w, h) in faces:
            face_img = frame[y:y + h, x:x + w]
            face_resized = cv2.resize(face_img, (224, 224))
            face_input = np.expand_dims(face_resized, axis=0) / 255.0

            prediction = model.predict(face_input, verbose=0)
            class_index = np.argmax(prediction)
            confidence = prediction[0][class_index]
            label = label_map.get(class_index, "Unknown")

            # Show prediction result
            print(f"🧠 Prediction: {prediction}")
            print(f"📊 Confidence: {confidence:.2f}")
            print(f"🧾 Result: {label.upper()}")

            # Display result on frame
            result_text = f"{label.upper()} ({confidence:.2f})"
            color = (0, 255, 0) if label == "with_mask" else (0, 0, 255)
            cv2.putText(frame, result_text, (x, y - 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 3)

            cv2.imshow("📷 Mask Detection Result", frame)
            cv2.waitKey(3000)  # Show for 3 seconds

    elif key == ord('q'):
        print("👋 Exiting.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ⚠️ Failed to load label encoder. Using fallback label map.
# 📷 Camera started. Press 's' to scan, 'q' to quit.
# 📸 Scanning face...
# 🧠 Prediction: [[0.97168416]]
# 📊 Confidence: 0.97
# 🧾 Result: WITH_MASK
# 🧠 Prediction: [[0.20183451]]
# 📊 Confidence: 0.20
# 🧾 Result: WITH_MASK
# 📸 Scanning face...
# 🧠 Prediction: [[0.9767584]]
# 📊 Confidence: 0.98
# 🧾 Result: WITH_MASK
# 👋 Exiting.

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Label map for binary classification ===
label_map = {
    1: "without_mask",
    0: "with_mask"
}

# === Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        face_img = frame[y:y+h, x:x+w]
        face_img_resized = cv2.resize(face_img, (224, 224))
        face_input = np.expand_dims(face_img_resized, axis=0) / 255.0

        prediction = model.predict(face_input, verbose=0)
        prob = prediction[0][0]

        class_index = 1 if prob > 0.5 else 0
        label = label_map[class_index]

        color = (0, 255, 0) if class_index == 0 else (0, 0, 255)
        label_text = "With Mask" if class_index == 0 else "No Mask"

        # Draw rectangle and label (without accuracy value)
        cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(frame, label_text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.

# %%
import cv2
import numpy as np
import threading
from playsound import playsound
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Label map for binary classification ===
# 0 → with_mask, 1 → without_mask
label_map = {
    0: "with_mask",
    1: "without_mask"
}

# === Paths to your audio files ===
AUDIO_FILES = {
    "with_mask": "audio/with_mask.wav",
    "without_mask": "audio/without_mask.wav"
}

def play_audio_async(path):
    """Play audio in a separate thread (non‑blocking)."""
    threading.Thread(target=playsound, args=(path,), daemon=True).start()

# === Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 'q' to quit.")

last_label = None

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)
    gray  = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        # extract and prepare face ROI
        face_roi = frame[y:y+h, x:x+w]
        face_resized = cv2.resize(face_roi, (224, 224))
        face_input   = np.expand_dims(face_resized, axis=0) / 255.0

        # model prediction (sigmoid)
        prob = model.predict(face_input, verbose=0)[0][0]
        class_index = 1 if prob > 0.5 else 0
        label = label_map[class_index]

        # only play audio when label changes
        if label != last_label:
            play_audio_async(AUDIO_FILES[label])
            last_label = label

        # draw bounding box + label
        color = (0,255,0) if class_index==0 else (0,0,255)
        text  = "With Mask" if class_index==0 else "No Mask"
        cv2.rectangle(frame, (x,y), (x+w,y+h), color, 2)
        cv2.putText(frame, text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.

# %%
import cv2
import numpy as np
import threading
import time
from playsound import playsound
from tensorflow.keras.models import load_model

# === Load trained model ===
model = load_model("model/mask_detection_cnn_final.h5")

# === Label map for binary classification ===
label_map = {
    0: "with_mask",
    1: "without_mask"
}

# === Paths to your audio files ===
AUDIO_FILES = {
    "with_mask": "audio/with_mask.wav",
    "without_mask": "audio/without_mask.wav"
}

def play_audio_async(path):
    threading.Thread(target=playsound, args=(path,), daemon=True).start()

# === Haar Cascade for face detection ===
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

# === Start webcam ===
cap = cv2.VideoCapture(0)
print("📷 Camera started. Press 'q' to quit.")

last_label = None
last_audio_time = 0
COOLDOWN = 3.0  # seconds

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read from camera.")
        break

    frame = cv2.flip(frame, 1)
    gray  = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        roi = frame[y:y+h, x:x+w]
        face = cv2.resize(roi, (224, 224))
        inp  = np.expand_dims(face, axis=0) / 255.0

        prob = model.predict(inp, verbose=0)[0][0]
        cls  = 1 if prob>0.5 else 0
        label= label_map[cls]

        now = time.time()
        # only play if label changed AND cooldown expired
        if label != last_label and (now - last_audio_time) >= COOLDOWN:
            play_audio_async(AUDIO_FILES[label])
            last_label = label
            last_audio_time = now

        # draw box + label
        color = (0,255,0) if cls==0 else (0,0,255)
        text  = "With Mask" if cls==0 else "No Mask"
        cv2.rectangle(frame, (x,y),(x+w,y+h), color, 2)
        cv2.putText(frame, text, (x, y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    cv2.imshow("Mask Detection Live Feed", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 📷 Camera started. Press 'q' to quit.
